# %%
import torch

memory = torch.rand(256, 22*22, 16)
tgt = torch.rand(256, 22*22, 16)

model = torch.nn.Transformer(batch_first=True, d_model=16, nhead=1, dim_feedforward=32, num_encoder_layers=1, num_decoder_layers=1)
model.to("cuda")
model(tgt=tgt.to("cuda"), src=memory.to("cuda"))
# Out:
# tensor([[[-0.5010, -0.1131, -1.5313,  ...,  0.7619, -0.3943,  1.9518],
#          [-1.0275, -0.8688, -0.5264,  ...,  0.7619, -0.9831,  2.1765],
#          [-1.2717, -1.1788, -0.0067,  ...,  1.2233,  0.2704,  1.7615],
#          ...,
#          [ 0.3915, -1.0868, -0.5165,  ...,  0.4987, -0.2284,  2.0322],
#          [-0.8124, -0.2055, -0.9827,  ...,  0.4256, -0.1702,  1.5103],
#          [-0.2864, -0.7460, -1.0969,  ...,  0.1794, -0.2512,  1.5691]],
#
#         [[ 0.8651, -1.1712, -0.8709,  ...,  1.8970,  0.1696,  0.9779],
#          [-0.3772, -1.3264, -0.6046,  ..., -0.0457, -0.2563,  1.7692],
#          [-0.9214, -0.8678, -0.2912,  ...,  0.2304, -0.1649,  1.8140],
#          ...,
#          [-0.3798, -0.1747, -0.9044,  ...,  0.1013, -1.0697,  2.2326],
#          [-1.1253, -0.5889, -0.6887,  ..., -0.2198, -0.4476,  1.6719],
#          [ 0.5106, -0.6425, -0.4209,  ...,  0.3722, -0.4909,  2.1072]],
#
#         [[-0.8547, -0.2443, -1.2238,  ...,  0.6394, -1.2323,  1.5973],
# ...
